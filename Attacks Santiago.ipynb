# %%
import pandas as pd

# %%
# !pwd
# Out:
# /Users/santiaguilar/ironhack/projects

# %%
df = pd.read_csv("attacks (1).csv", index_col=0, encoding='latin-1')

# %%
pd.options.display.max_rows = len(df)
pd.options.display.max_rows
# Out:
# 25723

# %%
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'Area', 'Location', 'Activity',
#        'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time', 'Species ',
#        'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
df.sample(100)
# Out:
#                               Date    Year          Type  \
# Case Number
# NaN                            NaN     NaN           NaN
# NaN                            NaN     NaN           NaN
# NaN                            NaN     NaN           NaN
# 2011.09.20             20-Sep-2011  2011.0          Boat
# NaN                            NaN     NaN           NaN
# NaN                            NaN     NaN           NaN
# NaN                            NaN     NaN           NaN
# NaN                            NaN     NaN           NaN
# 0                              NaN     NaN           NaN
# NaN                            NaN     NaN           NaN
# NaN                            NaN     NaN           NaN
# 2011.06.24             24-Jun-2011  2011.0    Unprovoked
# 2010.10.20             20-Oct-2010  2010.0    Unprovoked
# NaN                            NaN     NaN           NaN
# NaN                            NaN     NaN           NaN
# ...

# %%
df = df.dropna(how='all')

# %%
df.sample(100)
# Out:
#                                    Date    Year          Type  \
# Case Number
# 1860.03.27                  27-Mar-1860  1860.0  Sea Disaster
# 1961.12.27                  27-Dec-1961  1961.0      Provoked
# 1988.02.15                  15-Feb-1988  1988.0          Boat
# 1967.12.14                  14-Dec-1967  1967.0      Provoked
# 2003.06.30                  30-Jun-2003  2003.0    Unprovoked
# 1955.01.15                  15-Jan-1955  1955.0    Unprovoked
# 1954.12.09                  09-Dec-1954  1954.0    Unprovoked
# 1957.07.24                  24-Jul-1957  1957.0      Provoked
# 1864.01.27.R       Reported 27-Jan-1864  1864.0    Unprovoked
# 1987.02.19                  19-Feb-1987  1987.0  Sea Disaster
# 1960.11.00.c                   Nov-1960  1960.0      Provoked
# 1832.01.23.R       Reported 23-Jan-1832  1832.0    Unprovoked
# 1917.09.00                     Sep-1917  1917.0    Unprovoked
# ND.0069                     Before 1962     0.0    Unprovoked
# ...

# %%
pd.options.display.max_rows = len(df)
pd.options.display.max_rows
# Out:
# 6309

# %%
df['Unnamed: 22'].isnull().value_counts()
# Out:
# True     6308
# False       1
# Name: Unnamed: 22, dtype: int64

# %%
df['Unnamed: 23'].isnull().value_counts()
# Out:
# True     6307
# False       2
# Name: Unnamed: 23, dtype: int64

# %%
df["Type"].unique()
# Out:
# array(['Boating', 'Unprovoked', 'Invalid', 'Provoked', 'Questionable',
#        'Sea Disaster', nan, 'Boat', 'Boatomg'], dtype=object)

# %%
df["Activity"].value_counts()
# Out:
# Surfing                                                                                                                                                                                                                                                           971
# Swimming                                                                                                                                                                                                                                                          869
# Fishing                                                                                                                                                                                                                                                           431
# ...
